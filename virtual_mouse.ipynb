# %%
# !pip install --upgrade pip setuptools wheel
# !pip install opencv-contrib-python==4.10.0.84
# !pip install mediapipe
# !pip install pyautogui
# !pip install numpy
# !pip install time
# !pip install math
# !pip install ctypes

import cv2
import mediapipe as mp
import pyautogui
import numpy as np
import time
import math
import ctypes

# ===================== Configuration =====================
# Webcam resolution
CAM_WIDTH, CAM_HEIGHT = 640, 480
FRAME_MARGIN = 50
SMOOTHING = 5

# Screen resolution
SCREEN_WIDTH, SCREEN_HEIGHT = pyautogui.size()

# Click cooldown (seconds)
CLICK_COOLDOWN = 0.5
YES_COOLDOWN = 1

# ===================== State Variables =====================
prev_x, prev_y = 0, 0
curr_x, curr_y = 0, 0
last_click_time = 0
last_yes_time = 0

# ===================== Setup Webcam =====================
cap = cv2.VideoCapture(0)
cap.set(3, CAM_WIDTH)
cap.set(4, CAM_HEIGHT)

if not cap.isOpened():
    print("❌ Camera not opened.")
    exit()

# ===================== Setup MediaPipe =====================
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1)
mp_draw = mp.solutions.drawing_utils

# ===================== Setup Window (Always on Top) =====================
cv2.namedWindow("Virtual Mouse", cv2.WINDOW_NORMAL)
cv2.resizeWindow("Virtual Mouse", 320, 240)
cv2.moveWindow("Virtual Mouse", 1200, 0)

hwnd = ctypes.windll.user32.FindWindowW(None, "Virtual Mouse")
ctypes.windll.user32.SetWindowPos(hwnd, -1, 0, 0, 0, 0, 0x0001 | 0x0002)

# ===================== Helper Functions =====================
def fingers_up(hand_landmarks):
    """Returns list of 5 elements (1=up, 0=down) for Thumb, Index, Middle, Ring, Pinky."""
    tips = [4, 8, 12, 16, 20]
    fingers = []

    # Thumb
    fingers.append(1 if hand_landmarks.landmark[tips[0]].x <
                    hand_landmarks.landmark[tips[0] - 1].x else 0)

    # Other fingers
    for i in range(1, 5):
        fingers.append(1 if hand_landmarks.landmark[tips[i]].y <
                        hand_landmarks.landmark[tips[i] - 2].y else 0)
    return fingers

def get_position(landmarks, idx):
    """Returns (x, y) position of landmark in webcam coordinates."""
    return int(landmarks.landmark[idx].x * CAM_WIDTH), int(landmarks.landmark[idx].y * CAM_HEIGHT)

def move_cursor(index_x, index_y):
    """Moves the cursor smoothly based on index finger position."""
    global prev_x, prev_y, curr_x, curr_y
    target_x = np.interp(index_x, (FRAME_MARGIN, CAM_WIDTH - FRAME_MARGIN), (0, SCREEN_WIDTH))
    target_y = np.interp(index_y, (FRAME_MARGIN, CAM_HEIGHT - FRAME_MARGIN), (0, SCREEN_HEIGHT))

    curr_x = prev_x + (target_x - prev_x) / SMOOTHING
    curr_y = prev_y + (target_y - prev_y) / SMOOTHING

    pyautogui.moveTo(curr_x, curr_y)
    prev_x, prev_y = curr_x, curr_y

# ===================== Main Loop =====================
while True:
    success, img = cap.read()
    if not success:
        print("❌ Failed to read frame")
        continue

    img = cv2.flip(img, 1)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(img_rgb)

    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_draw.draw_landmarks(img, hand_landmarks, mp_hands.HAND_CONNECTIONS)

            fingers = fingers_up(hand_landmarks)
            index_x, index_y = get_position(hand_landmarks, 8)
            thumb_x, thumb_y = get_position(hand_landmarks, 4)
            middle_x, middle_y = get_position(hand_landmarks, 12)

            now = time.time()

            # Cursor movement: Only Index up
            if fingers[1] == 1 and sum(fingers) == 1:
                move_cursor(index_x, index_y)

            # Left Click: Thumb + Index close
            if math.hypot(index_x - thumb_x, index_y - thumb_y) < 40 and fingers[0] == 1 and fingers[1] == 1:
                if now - last_click_time > CLICK_COOLDOWN:
                    pyautogui.click()
                    print("🖱️ Left Click")
                    last_click_time = now

            # Right Click: Thumb + Middle close
            if math.hypot(middle_x - thumb_x, middle_y - thumb_y) < 40 and fingers[0] == 1 and fingers[2] == 1:
                if now - last_click_time > CLICK_COOLDOWN:
                    pyautogui.click(button='right')
                    print("🖱️ Right Click")
                    last_click_time = now

            # YES Gesture: Index + Middle up only
            if fingers[1] == 1 and fingers[2] == 1 and sum(fingers) == 2:
                if now - last_yes_time > YES_COOLDOWN:
                    print("✅ YES Detected!")
                    last_yes_time = now

    cv2.imshow("Virtual Mouse", img)

    if cv2.waitKey(1) & 0xFF == 27:  # ESC to exit
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Requirement already satisfied: pip in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (25.3)
# Requirement already satisfied: setuptools in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (80.9.0)
# Requirement already satisfied: wheel in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (0.45.1)
# Requirement already satisfied: opencv-contrib-python==4.10.0.84 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from opencv-contrib-python==4.10.0.84) (1.26.4)
# Requirement already satisfied: mediapipe in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (0.10.21)
# Requirement already satisfied: absl-py in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from mediapipe) (2.3.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from mediapipe) (25.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from mediapipe) (25.9.23)
# Requirement already satisfied: jax in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from mediapipe) (0.7.1)
# Requirement already satisfied: jaxlib in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from mediapipe) (0.7.1)
# Requirement already satisfied: matplotlib in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from mediapipe) (3.10.7)
# Requirement already satisfied: numpy<2 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from mediapipe) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from mediapipe) (0.5.3)
# Requirement already satisfied: sentencepiece in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from mediapipe) (0.2.1)
# Requirement already satisfied: CFFI>=1.0 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.23)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from jax->mediapipe) (0.5.4)
# Requirement already satisfied: opt_einsum in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from jax->mediapipe) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from matplotlib->mediapipe) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from matplotlib->mediapipe) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from matplotlib->mediapipe) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from matplotlib->mediapipe) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from matplotlib->mediapipe) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Requirement already satisfied: pyautogui in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (0.9.54)
# Requirement already satisfied: pymsgbox in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from pyautogui) (2.0.1)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from pyautogui) (1.0.1)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: Pillow>=9.3.0 in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (12.0.0)
# Requirement already satisfied: pyperclip in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (from mouseinfo->pyautogui) (1.11.0)
# Requirement already satisfied: numpy in c:\users\user\desktop\ml\virtual_mouse\.venv\lib\site-packages (1.26.4)
# ERROR: Could not find a version that satisfies the requirement time (from versions: none)
# ERROR: No matching distribution found for time
# ERROR: Could not find a version that satisfies the requirement math (from versions: none)
# ERROR: No matching distribution found for math
# ERROR: Could not find a version that satisfies the requirement ctypes (from versions: none)
# ERROR: No matching distribution found for ctypes
# 🖱️ Left Click
# ✅ YES Detected!
# ✅ YES Detected!
# 🖱️ Left Click
# 🖱️ Left Click
# ✅ YES Detected!
